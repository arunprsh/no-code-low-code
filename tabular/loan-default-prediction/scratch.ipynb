# %%
import pandas as pd

# %%
df = pd.read_csv('./data/loans.csv')

# %%
df.head(5)
# Out:
#    loan_amount  funded_amount_by_investors  term  interest_rate  installment  \
# 0         5000                      4975.0    36          10.65       162.87
# 1         2500                      2500.0    60          15.27        59.83
# 2         2400                      2400.0    36          15.96        84.33
# 3        10000                     10000.0    36          13.49       339.31
# 4         5000                      5000.0    36           7.90       156.46
#
#   grade sub_grade  employment_length home_ownership  annual_income  ...  \
# 0     B        B2                 10           RENT        24000.0  ...
# 1     C        C4                  0           RENT        30000.0  ...
# 2     C        C5                 10           RENT        12252.0  ...
# 3     C        C1                 10           RENT        49200.0  ...
# 4     A        A4                  3           RENT        36000.0  ...
#
# ...

# %%
df.columns
# Out:
# Index(['loan_amount', 'funded_amount_by_investors', 'term', 'interest_rate',
#        'installment', 'grade', 'sub_grade', 'employment_length',
#        'home_ownership', 'annual_income', 'verification_status',
#        'issued_amount', 'loan_status', 'purpose', 'dti',
#        'earliest_credit_line', 'inquiries_last_6_months', 'open_credit_lines',
#        'derogatory_public_records', 'revolving_line_utilization_rate',
#        'total_credit_lines'],
#       dtype='object')
